# %%
#pytorch-lightning install
# !pip install pytorch-lightning

# %%
# !pip install wandb

# %%
#imports
import torch
import pytorch_lightning as pl
import os
import pandas as pd
from torch.utils.data import Dataset
from torch.nn import CrossEntropyLoss
import numpy as np

# %%
#Number of different cancer types in dataset
num_classes = len(set([x.split('.')[1] for x in os.listdir('./methyl_files')]))
print(num_classes)
# Out:
# 12

# %%
#Value counts of dataset
type_list = [x.split('.')[1] for x in os.listdir('./methyl_files')]
for x in set([x.split('.')[1] for x in os.listdir('./methyl_files')]):
    print(x)
    print(type_list.count(x))
# Out:
# edu_KIRC
# 217
# edu_LUAD
# 126
# edu_UCEC
# 117
# edu_OV
# 592
# edu_KIRP
# 16
# edu_BRCA
# 313
# edu_GBM
# 287
# edu_COAD
# 166
# edu_LAML
# 140
# edu_STAD
# 48
# edu_READ
# 68
# edu_LUSC
# 133

# %%
#Dataset object input
files_list = os.listdir('./methyl_files')
#labels_dict
labels_dict = dict(zip(set(type_list),range(12)))
print(labels_dict)
# Out:
# {'edu_KIRC': 0, 'edu_LUAD': 1, 'edu_UCEC': 2, 'edu_OV': 3, 'edu_KIRP': 4, 'edu_BRCA': 5, 'edu_GBM': 6, 'edu_COAD': 7, 'edu_LAML': 8, 'edu_STAD': 9, 'edu_READ': 10, 'edu_LUSC': 11}

# %%
#Getting gene list
temp_df = pd.read_csv("./methyl_files/" + files_list[0])  
gene_list = temp_df['Unnamed: 0'].tolist()

# %%
temp_df.set_index('Unnamed: 0',inplace=True)

# %%
lens_list = []

# %%
#pytorch dataset object
class MethylDataset(Dataset):
    def __init__(self,files_list,labels_dict):
        self.labels = [labels_dict[x.split('.')[1]] for x in files_list]
        self.files_list = files_list
    def __len__(self):
        return len(self.labels)
    def __getitem__(self, idx):
        temp_df = pd.read_csv("./methyl_files/" + self.files_list[idx])     
        temp_df.set_index("Unnamed: 0",inplace=True)
        diff_list = list(set(gene_list) - set(temp_df.index.tolist()))
        for gene in diff_list:
            temp_df.loc[gene] = '0'    
        avg = lambda x: sum(x)/len(x)
        temp_df['beta_values_avg'] = temp_df['beta_values'].apply(lambda x : avg([float(y) for y in x.split(';')]))
        temp_df.sort_index(inplace=True)
        list_beta = temp_df['beta_values_avg'].tolist()
        out_list = [0]*num_classes
        out_list[self.labels[idx]] = 1
        out = (torch.Tensor(list_beta), torch.Tensor(out_list))
        return out

# %%
test_dataset = MethylDataset(files_list,labels_dict)

# %%
F = torch.nn.BCEWithLogitsLoss()
#from torch.nn import functional as F
class MethylModel(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.l1 = torch.nn.Linear(17661, 1000)
        self.l2 = torch.nn.Linear(1000, 12)    

    def forward(self, x):
        X = self.l1(x)
        X1 = self.l2(X)
        return torch.sigmoid(X1)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_hat = self(x)
        loss = F(y_hat, y)
        print("train_loss: ",loss)
        self.log("train_loss", loss,prog_bar=True)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=1e-5)

# %%
model = MethylModel()

# %%
train_ds, test_ds = torch.utils.data.random_split(test_dataset, [2000, 223])

# %%
train_dl = torch.utils.data.DataLoader(train_ds)
val_dl = torch.utils.data.DataLoader(test_ds)

# %%
wandb_logger = pl.loggers.WandbLogger()

# %%
trainer = pl.Trainer(log_every_n_steps=1,enable_progress_bar=True,logger=wandb_logger)
trainer.fit(model, train_dl, val_dl)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pytorch_lightning/trainer/configuration_validator.py:120: UserWarning: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
#   rank_zero_warn("You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.")
#
#   | Name | Type   | Params
# --------------------------------
# 0 | l1   | Linear | 17.7 M
# 1 | l2   | Linear | 12.0 K
# --------------------------------
# 17.7 M    Trainable params
# 0         Non-trainable params
# 17.7 M    Total params
# 70.696    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# train_loss:  tensor(0.9331, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:  ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /home/ec2-user/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/dufaultc/uncategorized/runs/m1sgqyej" target="_blank">zesty-dawn-32</a></strong> to <a href="https://wandb.ai/dufaultc/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# train_loss:  tensor(0.9058, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.9042, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.8652, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.8645, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.8340, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.8214, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.8027, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.8026, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7786, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7731, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7593, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7454, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7655, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7416, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7305, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7362, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7239, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7246, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7191, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7100, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7155, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7131, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7134, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7089, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7057, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7078, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7092, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7067, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7031, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7025, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7026, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7163, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7031, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7040, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7011, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6985, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6980, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6976, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7055, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6969, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7072, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6988, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6992, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6949, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7014, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6979, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7008, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6978, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6986, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6979, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6985, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6991, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7000, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6965, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6969, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6948, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6980, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6968, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6971, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6967, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6996, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7049, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6971, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6970, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6959, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6957, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6958, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6993, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6959, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6956, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6949, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7011, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6957, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6951, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6958, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6967, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6960, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6960, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6952, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6954, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6962, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6949, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6951, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6954, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6958, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6967, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6974, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6952, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6962, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6966, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6961, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6954, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6957, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6955, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6963, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6966, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6978, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6955, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7037, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6953, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6960, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6951, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6946, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6953, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6949, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6952, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6951, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6952, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6961, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6970, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6946, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6946, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7000, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6985, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6948, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6952, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.7012, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6948, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6941, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6946, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6950, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6944, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6960, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6946, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6945, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6943, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6952, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6947, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6940, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6939, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6937, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6958, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6942, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# ...
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6936, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6938, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6935, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6934, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6931, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6933, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# train_loss:  tensor(0.6932, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py:688: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
